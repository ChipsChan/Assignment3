# %% [markdown]
# ## Dataset
# ### Online News Popularity

# %% [markdown]
# This dataset, named Online News Popularity, contains data related to online news articles and their popularity. It's designed to facilitate the study of factors that affect the popularity of online news.

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Get Data

# %%
News_pop = pd.read_csv('E:/DH/collecting data/OnlineNewsPopularity/OnlineNewsPopularity.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# ## Overview

# %% [markdown]
# To have a random look of this whole dataset.

# %%
News_pop.sample(10)
# Out:
#                                                      url   timedelta  \
# 8012   http://mashable.com/2013/06/06/verizon-just-sa...       581.0
# 33816  http://mashable.com/2014/10/01/feeling-nuts-te...        99.0
# 9858   http://mashable.com/2013/07/12/twitter-for-ent...       545.0
# 20849  http://mashable.com/2014/02/22/house-of-cards-...       320.0
# 18035  http://mashable.com/2013/12/25/ukranian-journa...       379.0
# 39347  http://mashable.com/2014/12/21/nypd-cop-killer...        15.0
# 32016          http://mashable.com/2014/09/03/napa-maps/       127.0
# 22553  http://mashable.com/2014/03/28/begin-again-tra...       286.0
# 9800   http://mashable.com/2013/07/12/apple-store-bui...       545.0
# 21793  http://mashable.com/2014/03/13/game-of-thrones...       301.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 8012               9.0              262.0          0.580153
# 33816             10.0                0.0          0.000000
# ...

# %% [markdown]
# Generate information about all the columns in the data

# %%
News_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
# ...

# %% [markdown]
# Make a histogram of the DataFrame

# %%
News_pop.hist(figsize=(30,30))
# Out:
# array([[<Axes: title={'center': ' timedelta'}>,
#         <Axes: title={'center': ' n_tokens_title'}>,
#         <Axes: title={'center': ' n_tokens_content'}>,
#         <Axes: title={'center': ' n_unique_tokens'}>,
#         <Axes: title={'center': ' n_non_stop_words'}>,
#         <Axes: title={'center': ' n_non_stop_unique_tokens'}>,
#         <Axes: title={'center': ' num_hrefs'}>,
#         <Axes: title={'center': ' num_self_hrefs'}>],
#        [<Axes: title={'center': ' num_imgs'}>,
#         <Axes: title={'center': ' num_videos'}>,
#         <Axes: title={'center': ' average_token_length'}>,
#         <Axes: title={'center': ' num_keywords'}>,
#         <Axes: title={'center': ' data_channel_is_lifestyle'}>,
#         <Axes: title={'center': ' data_channel_is_entertainment'}>,
#         <Axes: title={'center': ' data_channel_is_bus'}>,
#         <Axes: title={'center': ' data_channel_is_socmed'}>],
#        [<Axes: title={'center': ' data_channel_is_tech'}>,
# ...

# %%
News_pop.describe(include='all')
# Out:
#                                                       url     timedelta  \
# count                                               39644  39644.000000
# unique                                              39644           NaN
# top     http://mashable.com/2013/01/07/amazon-instant-...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    354.530471
# std                                                   NaN    214.163767
# min                                                   NaN      8.000000
# 25%                                                   NaN    164.000000
# 50%                                                   NaN    339.000000
# 75%                                                   NaN    542.000000
# max                                                   NaN    731.000000
#
#          n_tokens_title   n_tokens_content   n_unique_tokens  \
# ...

# %% [markdown]
# ## Drop Rows

# %%
News_pop[News_pop[' n_tokens_title'] > 15]
# Out:
#                                                      url   timedelta  \
# 240    http://mashable.com/2013/01/10/report-steve-jo...       728.0
# 245    http://mashable.com/2013/01/10/ski-brogues-hertz/       728.0
# 340    http://mashable.com/2013/01/13/iphone-strings-...       725.0
# 588    http://mashable.com/2013/01/17/apple-loses-pat...       721.0
# 652    http://mashable.com/2013/01/18/al-gore-just-go...       720.0
# ...                                                  ...         ...
# 39502  http://mashable.com/2014/12/24/christmas-nativ...        11.0
# 39504  http://mashable.com/2014/12/24/drake-holiday-c...        11.0
# 39528  http://mashable.com/2014/12/24/sony-hack-publi...        10.0
# 39534  http://mashable.com/2014/12/24/the-interview-t...        10.0
# 39604  http://mashable.com/2014/12/26/pig-savoring-tr...         9.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 240               16.0              487.0          0.519588
# ...

# %%
News_pop = News_pop.drop(News_pop[News_pop[' n_tokens_title'] > 15].index)

# %%
News_pop
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0                 12.0              219.0          0.663594
# ...

# %%
News_pop[News_pop[' n_tokens_title'] > 15]
# Out:
# Empty DataFrame
# ...
